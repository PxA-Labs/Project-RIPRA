# %% [markdown]
# # RIPRA Slope Completion AI Training
#
# This notebook trains the slope-completion LSTM using a free Kaggle GPU.
#
# ### Instructions:
# 1. In the right sidebar, click **Add Data** and upload your `dataset_large.npz`.
# 2. Make sure the Accelerator is set to **GPU T4x2** or **P100**.
# 3. Run all cells!

# %%
# 1. Clone the repository so we have the training scripts
# !git clone https://github.com/Shlok-Parekh09/Project-RIPRA.git
# %cd Project-RIPRA/rippra

# %%
# 2. Find your uploaded dataset (update the path if your dataset name is different)
import glob
dataset_path = glob.glob("/kaggle/input/**/*.npz", recursive=True)[0]
print(f"Found dataset at: {dataset_path}")

# %%
# 3. Run the training script on GPU
# !python ml/train_sequence.py --task complete_slopes --dataset {dataset_path} --epochs 50 --batch_size 256

# %%
# 4. Export the ONNX model
# !python ml/export_onnx.py --output_dir /kaggle/working/onnx_models

# %% [markdown]
# ### Done!
# Now look at the **Output** section in the right sidebar under `/kaggle/working/onnx_models` and download the `slope_completion_lstm.onnx` file to your laptop!
